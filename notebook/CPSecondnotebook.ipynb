# %% [markdown]
# # segmenting and clustering neighborhoods in toronto

# %% [markdown]
# #### In this second notebook we get geographical coordinates of neighborhoods in toronto
# #### we will use data.csv file created in previous notebook

# %%
# import neccessary libraries
import pandas as pd
#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into longitude and latitude

# %%
data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 postal_code           Borough  \
# 0           0         M3A        North York
# 1           1         M4A        North York
# 2           2         M5A  Downtown Toronto
# 3           3         M6A        North York
# 4           4         M7A  Downtown Toronto
#
#                                   Neighborhood
# 0                                    Parkwoods
# 1                             Victoria Village
# 2                    Regent Park, Harbourfront
# 3             Lawrence Manor, Lawrence Heights
# 4  Queen's Park, Ontario Provincial Government

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.head()
# Out:
#   postal_code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# #### split multiple neighborhood in neighborhood columns

# %%
data_new=(data.set_index(data.columns.drop('Neighborhood', 1).to_list()).Neighborhood.str.split(',', expand=True).stack().reset_index().rename(columns={0:'Neighborhood'}).loc[:, data.columns])
data_new.head()
# Out:
#   postal_code           Borough      Neighborhood
# 0         M3A        North York         Parkwoods
# 1         M4A        North York  Victoria Village
# 2         M5A  Downtown Toronto       Regent Park
# 3         M5A  Downtown Toronto      Harbourfront
# 4         M6A        North York    Lawrence Manor

# %%
data_new['Latitude']=''
data_new['Longitude']=''
data_new.head()
# Out:
#   postal_code           Borough      Neighborhood Latitude Longitude
# 0         M3A        North York         Parkwoods
# 1         M4A        North York  Victoria Village
# 2         M5A  Downtown Toronto       Regent Park
# 3         M5A  Downtown Toronto      Harbourfront
# 4         M6A        North York    Lawrence Manor

# %%
data_new.shape
# Out:
# (217, 5)

# %%
# now we get geographical coordinates of neighborhoods
drop_unknown = []
geolocator = Nominatim(user_agent="toronto_explorer")
for index, row in data_new.iterrows():
    address = row['Neighborhood'] + ', Toronto'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        data_new.loc[index, 'Latitude'] = latitude
        data_new.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        drop_unknown.append(index)
# Out:
# The geograpical coordinate of Parkwoods, Toronto are 43.7611243, -79.3240594.
# The geograpical coordinate of Victoria Village, Toronto are 43.732658, -79.3111892.
# The geograpical coordinate of Regent Park, Toronto are 43.6607056, -79.3604569.
# The geograpical coordinate of  Harbourfront, Toronto are 43.6400801, -79.3801495.
# The geograpical coordinate of Lawrence Manor, Toronto are 43.7220788, -79.4375067.
# The geograpical coordinate of  Lawrence Heights, Toronto are 43.7227784, -79.4509332.
# The geograpical coordinate of Queen's Park, Toronto are 43.659659, -79.3903399.
# Cannot do:  Ontario Provincial Government, Toronto, will drop index: 7
# The geograpical coordinate of Islington Avenue, Toronto are 43.6214816, -79.5136854.
# The geograpical coordinate of  Humber Valley Village, Toronto are 43.6664717, -79.5243136.
# The geograpical coordinate of Malvern, Toronto are 43.8091955, -79.2217008.
# The geograpical coordinate of  Rouge, Toronto are 43.8049304, -79.1658374.
# The geograpical coordinate of Don Mills, Toronto are 43.775347, -79.3459439.
# The geograpical coordinate of Parkview Hill, Toronto are 43.7062977, -79.3219073.
# The geograpical coordinate of  Woodbine Gardens, Toronto are 43.7120785, -79.3025673.
# The geograpical coordinate of Garden District, Toronto are 43.6564995, -79.3771141.
# The geograpical coordinate of  Ryerson, Toronto are 43.65846945, -79.37899327245886.
# The geograpical coordinate of Glencairn, Toronto are 43.7087117, -79.4406853.
# The geograpical coordinate of West Deane Park, Toronto are 43.6631995, -79.5685684.
# The geograpical coordinate of  Princess Gardens, Toronto are 43.6404664, -79.3912237.
# The geograpical coordinate of  Martin Grove, Toronto are 43.6534817, -79.3839347.
# The geograpical coordinate of  Islington, Toronto are 43.645335, -79.5248163.
# The geograpical coordinate of  Cloverdale, Toronto are 43.633637, -79.5497447.
# The geograpical coordinate of Rouge Hill, Toronto are 43.7802711, -79.1304992.
# The geograpical coordinate of  Port Union, Toronto are 43.7755039, -79.1349765.
# The geograpical coordinate of  Highland Creek, Toronto are 43.7901172, -79.1733344.
# The geograpical coordinate of Don Mills, Toronto are 43.775347, -79.3459439.
# The geograpical coordinate of Woodbine Heights, Toronto are 43.69992, -79.319279.
# The geograpical coordinate of St. James Town, Toronto are 43.6694032, -79.3727041.
# The geograpical coordinate of Humewood-Cedarvale, Toronto are 43.6883215, -79.4280805.
# The geograpical coordinate of Eringate, Toronto are 43.6622732, -79.5765162.
# The geograpical coordinate of  Bloordale Gardens, Toronto are 43.6353169, -79.5636744.
# The geograpical coordinate of  Old Burnhamthorpe, Toronto are 43.6393732, -79.5843869.
# The geograpical coordinate of  Markland Wood, Toronto are 43.63123865, -79.58543401986114.
# The geograpical coordinate of Guildwood, Toronto are 43.7552251, -79.1982293.
# The geograpical coordinate of  Morningside, Toronto are 43.7826012, -79.2049579.
# The geograpical coordinate of  West Hill, Toronto are 43.7689144, -79.1872905.
# The geograpical coordinate of The Beaches, Toronto are 43.6710244, -79.296712.
# The geograpical coordinate of Berczy Park, Toronto are 43.64798435, -79.37539591138858.
# Cannot do: Caledonia-Fairbanks, Toronto, will drop index: 39
# The geograpical coordinate of Woburn, Toronto are 43.7598243, -79.2252908.
# The geograpical coordinate of Leaside, Toronto are 43.7047983, -79.3680904.
# The geograpical coordinate of Central Bay Street, Toronto are 43.6526511, -79.3825029.
# The geograpical coordinate of Christie, Toronto are 43.6641106, -79.4184051.
# The geograpical coordinate of Cedarbrae, Toronto are 43.75646655, -79.22669244258802.
# The geograpical coordinate of Hillcrest Village, Toronto are 43.6816953, -79.4257118.
# The geograpical coordinate of Bathurst Manor, Toronto are 43.6655189, -79.4119373.
# The geograpical coordinate of  Wilson Heights, Toronto are 43.7405195, -79.4400172.
# The geograpical coordinate of  Downsview North, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of Thorncliffe Park, Toronto are 43.704553, -79.3454074.
# The geograpical coordinate of Richmond, Toronto are 43.6485875, -79.3913729.
# The geograpical coordinate of  Adelaide, Toronto are 43.6502975, -79.38047735048377.
# The geograpical coordinate of  King, Toronto are 43.6489494, -79.3777538.
# The geograpical coordinate of Dufferin, Toronto are 43.6602019, -79.4357191.
# The geograpical coordinate of  Dovercourt Village, Toronto are 43.6653069, -79.4326362.
# The geograpical coordinate of Scarborough Village, Toronto are 43.7437422, -79.2116324.
# The geograpical coordinate of Fairview, Toronto are 43.777758500000004, -79.34429375180316.
# The geograpical coordinate of  Henry Farm, Toronto are 43.7695089, -79.354296.
# The geograpical coordinate of  Oriole, Toronto are 43.765498, -79.3642688.
# The geograpical coordinate of Northwood Park, Toronto are 43.7541351, -79.50448.
# The geograpical coordinate of  York University, Toronto are 43.7743325, -79.50027054016516.
# The geograpical coordinate of East Toronto, Toronto are 43.6261221, -79.3950351.
# The geograpical coordinate of  Broadview North (Old East York), Toronto are 43.6839216, -79.3569421.
# The geograpical coordinate of Harbourfront East, Toronto are 43.6400801, -79.3801495.
# The geograpical coordinate of  Union Station, Toronto are 43.6446934, -79.38013200585965.
# The geograpical coordinate of  Toronto Islands, Toronto are 43.6230544, -79.39431563721035.
# The geograpical coordinate of Little Portugal, Toronto are 43.64741325, -79.43111632546047.
# The geograpical coordinate of  Trinity, Toronto are 43.665301549999995, -79.39525214965947.
# The geograpical coordinate of Kennedy Park, Toronto are 43.724878, -79.2539688.
# The geograpical coordinate of  Ionview, Toronto are 43.7359904, -79.2765146.
# The geograpical coordinate of  East Birchmount Park, Toronto are 43.7141672, -79.271109.
# The geograpical coordinate of Bayview Village, Toronto are 43.7691966, -79.3766617.
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of The Danforth West, Toronto are 43.6864333, -79.3003555.
# The geograpical coordinate of  Riverdale, Toronto are 43.6654704, -79.3525936.
# The geograpical coordinate of Toronto Dominion Centre, Toronto are 43.6473768, -79.3813719429129.
# The geograpical coordinate of  Design Exchange, Toronto are 43.6477412, -79.3801145.
# The geograpical coordinate of Brockton, Toronto are 43.6509173, -79.4400216.
# The geograpical coordinate of  Parkdale Village, Toronto are 43.6404954, -79.4368965.
# The geograpical coordinate of  Exhibition Place, Toronto are 43.6335207, -79.4177242473176.
# The geograpical coordinate of Golden Mile, Toronto are 43.7278414, -79.2876217.
# The geograpical coordinate of  Clairlea, Toronto are 43.7088231, -79.2959856.
# The geograpical coordinate of  Oakridge, Toronto are 43.6971738, -79.2748232.
# The geograpical coordinate of York Mills, Toronto are 43.7440391, -79.406657.
# The geograpical coordinate of  Silver Hills, Toronto are 43.7612224, -79.3683818.
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of India Bazaar, Toronto are 43.6722231, -79.3235032.
# The geograpical coordinate of  The Beaches West, Toronto are 43.6710244, -79.296712.
# The geograpical coordinate of Commerce Court, Toronto are 43.64809515, -79.37902543099575.
# The geograpical coordinate of  Victoria Hotel, Toronto are 43.66946915, -79.37326825.
# The geograpical coordinate of North Park, Toronto are 43.7186899, -79.4775337.
# The geograpical coordinate of  Maple Leaf Park, Toronto are 43.7158241, -79.49341621107953.
# The geograpical coordinate of  Upwood Park, Toronto are 43.708654499999994, -79.50254644741823.
# The geograpical coordinate of Humber Summit, Toronto are 43.7600778, -79.5717598.
# The geograpical coordinate of Cliffside, Toronto are 43.7111699, -79.2481769.
# The geograpical coordinate of  Cliffcrest, Toronto are 43.7218363, -79.2362138.
# The geograpical coordinate of  Scarborough Village West, Toronto are 43.7437422, -79.2116324.
# The geograpical coordinate of Willowdale, Toronto are 43.7615095, -79.4109234.
# The geograpical coordinate of  Newtonbrook, Toronto are 43.795986, -79.4130896.
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of Studio District, Toronto are 43.64958515, -79.39068322559326.
# The geograpical coordinate of Bedford Park, Toronto are 43.7373876, -79.4109253.
# The geograpical coordinate of  Lawrence Manor East, Toronto are 43.7220788, -79.4375067.
# Cannot do: Del Ray, Toronto, will drop index: 103
# The geograpical coordinate of  Mount Dennis, Toronto are 43.6869597, -79.4895513.
# Cannot do:  Keelsdale and Silverthorn, Toronto, will drop index: 105
# The geograpical coordinate of Humberlea, Toronto are 43.7213166, -79.5331605.
# The geograpical coordinate of  Emery, Toronto are 43.7520744, -79.5423657.
# The geograpical coordinate of Birch Cliff, Toronto are 43.6918051, -79.2644935.
# The geograpical coordinate of  Cliffside West, Toronto are 43.7111699, -79.2481769.
# The geograpical coordinate of Willowdale, Toronto are 43.7615095, -79.4109234.
# The geograpical coordinate of  Willowdale East, Toronto are 43.7615095, -79.4109234.
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of Lawrence Park, Toronto are 43.729199, -79.4032525.
# The geograpical coordinate of Roselawn, Toronto are 43.7074896, -79.4154939.
# The geograpical coordinate of Runnymede, Toronto are 43.6517026, -79.4759978.
# The geograpical coordinate of  The Junction North, Toronto are 43.6654775, -79.470352.
# The geograpical coordinate of Weston, Toronto are 43.7001608, -79.5162474.
# The geograpical coordinate of Dorset Park, Toronto are 43.7528467, -79.282067.
# The geograpical coordinate of  Wexford Heights, Toronto are 43.7432421, -79.304641.
# The geograpical coordinate of  Scarborough Town Centre, Toronto are 43.7761341, -79.25843763592165.
# The geograpical coordinate of York Mills West, Toronto are 43.7440391, -79.406657.
# The geograpical coordinate of Davisville North, Toronto are 43.697936, -79.3972908.
# The geograpical coordinate of Forest Hill North & West, Toronto are 43.701028, -79.4255998.
# The geograpical coordinate of  Forest Hill Road Park, Toronto are 43.6904693, -79.404891.
# The geograpical coordinate of High Park, Toronto are 43.6538668, -79.4668644.
# The geograpical coordinate of  The Junction South, Toronto are 43.6654775, -79.470352.
# The geograpical coordinate of Westmount, Toronto are 43.6936399, -79.5210426.
# The geograpical coordinate of Wexford, Toronto are 43.7453767, -79.2947155.
# The geograpical coordinate of  Maryvale, Toronto are 43.7590508, -79.3102297.
# The geograpical coordinate of Willowdale, Toronto are 43.7615095, -79.4109234.
# The geograpical coordinate of  Willowdale West, Toronto are 43.7615095, -79.4109234.
# The geograpical coordinate of North Toronto West, Toronto are 43.6465466, -79.4195263.
# The geograpical coordinate of  Lawrence Park, Toronto are 43.729199, -79.4032525.
# The geograpical coordinate of The Annex, Toronto are 43.6703377, -79.407117.
# The geograpical coordinate of  North Midtown, Toronto are 43.7057358, -79.39756691740916.
# The geograpical coordinate of  Yorkville, Toronto are 43.6713861, -79.3901677.
# The geograpical coordinate of Parkdale, Toronto are 43.6404954, -79.4368965.
# The geograpical coordinate of  Roncesvalles, Toronto are 43.6514426, -79.4510381.
# Cannot do: Canada Post Gateway Processing Centre, Toronto, will drop index: 139
# The geograpical coordinate of Kingsview Village, Toronto are 43.6995391, -79.5563459.
# The geograpical coordinate of  St. Phillips, Toronto are 43.7000483, -79.5437651.
# The geograpical coordinate of  Martin Grove Gardens, Toronto are 43.6873105, -79.561967.
# The geograpical coordinate of  Richview Gardens, Toronto are 43.6848335, -79.5482883.
# The geograpical coordinate of Agincourt, Toronto are 43.7853531, -79.2785494.
# The geograpical coordinate of Davisville, Toronto are 43.697936, -79.3972908.
# The geograpical coordinate of University of Toronto, Toronto are 43.663461999999996, -79.39775965337452.
# The geograpical coordinate of  Harbord, Toronto are 43.663461999999996, -79.39775965337452.
# The geograpical coordinate of Runnymede, Toronto are 43.6517026, -79.4759978.
# The geograpical coordinate of  Swansea, Toronto are 43.64494, -79.478313.
# The geograpical coordinate of Clarks Corners, Toronto are 43.7964095, -79.2977951.
# The geograpical coordinate of  Tam O'Shanter, Toronto are 43.7810454, -79.2980941.
# The geograpical coordinate of  Sullivan, Toronto are 43.7726802, -79.3159449.
# The geograpical coordinate of Moore Park, Toronto are 43.6903876, -79.3832965.
# The geograpical coordinate of  Summerhill East, Toronto are 43.6816776, -79.3905037.
# The geograpical coordinate of Kensington Market, Toronto are 43.6552136, -79.4022604.
# The geograpical coordinate of  Chinatown, Toronto are 43.6529237, -79.3980316.
# The geograpical coordinate of  Grange Park, Toronto are 43.652196599999996, -79.39231921757992.
# The geograpical coordinate of Milliken, Toronto are 43.8231743, -79.3017626.
# The geograpical coordinate of  Agincourt North, Toronto are 43.8080383, -79.2664391.
# The geograpical coordinate of  Steeles East, Toronto are 43.8161778, -79.3145378.
# The geograpical coordinate of  L'Amoreaux East, Toronto are 43.799003, -79.3059669.
# The geograpical coordinate of Summerhill West, Toronto are 43.6816776, -79.3905037.
# The geograpical coordinate of  Rathnelly, Toronto are 43.6790811, -79.4011087.
# The geograpical coordinate of  South Hill, Toronto are 43.6779261, -79.4057671.
# The geograpical coordinate of  Forest Hill SE, Toronto are 43.6935586, -79.4139023.
# The geograpical coordinate of  Deer Park, Toronto are 43.68809, -79.3940935.
# The geograpical coordinate of CN Tower, Toronto are 43.6425637, -79.38708718320467.
# The geograpical coordinate of  King and Spadina, Toronto are 43.6454561, -79.3949942.
# The geograpical coordinate of  Railway Lands, Toronto are 49.2653106, -123.2397129.
# The geograpical coordinate of  Harbourfront West, Toronto are 43.6400801, -79.3801495.
# The geograpical coordinate of  Bathurst Quay, Toronto are 43.6357905, -79.398329.
# The geograpical coordinate of  South Niagara, Toronto are 43.6440753, -79.4086982.
# The geograpical coordinate of  Island airport, Toronto are 43.65299685, -79.60066885188766.
# The geograpical coordinate of New Toronto, Toronto are 43.6007625, -79.505264.
# The geograpical coordinate of  Mimico South, Toronto are 43.6166773, -79.4968048.
# Cannot do:  Humber Bay Shores, Toronto, will drop index: 176
# The geograpical coordinate of South Steeles, Toronto are 43.8161778, -79.3145378.
# The geograpical coordinate of  Silverstone, Toronto are 43.749750899999995, -79.59911593109416.
# The geograpical coordinate of  Humbergate, Toronto are 43.678523999999996, -79.62912913064454.
# The geograpical coordinate of  Jamestown, Toronto are 43.7343476, -79.5847935.
# The geograpical coordinate of  Mount Olive, Toronto are 8.8748315, -73.9766442.
# Cannot do:  Beaumond Heights, Toronto, will drop index: 182
# The geograpical coordinate of  Thistletown, Toronto are 43.7372656, -79.5653169.
# The geograpical coordinate of  Albion Gardens, Toronto are 43.7416654, -79.58454336862486.
# The geograpical coordinate of Steeles West, Toronto are 43.8161778, -79.3145378.
# The geograpical coordinate of  L'Amoreaux West, Toronto are 43.799003, -79.3059669.
# The geograpical coordinate of Rosedale, Toronto are 43.6783556, -79.3807457.
# Cannot do: Stn A PO Boxes, Toronto, will drop index: 188
# The geograpical coordinate of Alderwood, Toronto are 43.6017173, -79.5452325.
# The geograpical coordinate of  Long Branch, Toronto are 43.59200455, -79.54536450659592.
# The geograpical coordinate of Northwest, Toronto are 43.6465466, -79.4195263.
# The geograpical coordinate of  West Humber - Clairville, Toronto are 43.72337025, -79.59745741095173.
# The geograpical coordinate of Upper Rouge, Toronto are 43.8049304, -79.1658374.
# The geograpical coordinate of St. James Town, Toronto are 43.6694032, -79.3727041.
# The geograpical coordinate of  Cabbagetown, Toronto are 43.6644734, -79.3669861.
# The geograpical coordinate of First Canadian Place, Toronto are 43.6487681, -79.38169179283025.
# The geograpical coordinate of  Underground city, Toronto are 43.7701454, -79.3748625.
# The geograpical coordinate of The Kingsway, Toronto are 43.6473811, -79.5113328.
# The geograpical coordinate of  Montgomery Road, Toronto are 43.6495722, -79.5199669.
# The geograpical coordinate of  Old Mill North, Toronto are 43.649826, -79.4943338.
# The geograpical coordinate of Church and Wellesley, Toronto are 43.6708625, -79.37279241253721.
# Cannot do: Business reply mail Processing Centre, Toronto, will drop index: 202
# Cannot do:  South Central Letter Processing Plant Toronto, Toronto, will drop index: 203
# The geograpical coordinate of Old Mill South, Toronto are 43.649826, -79.4943338.
# The geograpical coordinate of  King's Mill Park, Toronto are 43.6510895, -79.4920291.
# The geograpical coordinate of  Sunnylea, Toronto are 43.64159705, -79.5016654011084.
# The geograpical coordinate of  Humber Bay, Toronto are 43.6400463, -79.495028.
# The geograpical coordinate of  Mimico NE, Toronto are 43.6166773, -79.4968048.
# The geograpical coordinate of  The Queensway East, Toronto are 43.6093093, -79.5677317.
# The geograpical coordinate of  Royal York South East, Toronto are 43.6481827, -79.5112961.
# The geograpical coordinate of  Kingsway Park South East, Toronto are 43.6473811, -79.5113328.
# The geograpical coordinate of Mimico NW, Toronto are 43.6166773, -79.4968048.
# The geograpical coordinate of  The Queensway West, Toronto are 43.6236182, -79.5147637.
# Cannot do:  South of Bloor, Toronto, will drop index: 214
# The geograpical coordinate of  Kingsway Park South West, Toronto are 43.6473811, -79.5113328.
# The geograpical coordinate of  Royal York South West, Toronto are 43.6481827, -79.5112961.

# %%
data_new.head()
# Out:
#   postal_code           Borough      Neighborhood Latitude Longitude
# 0         M3A        North York         Parkwoods  43.7611  -79.3241
# 1         M4A        North York  Victoria Village  43.7327  -79.3112
# 2         M5A  Downtown Toronto       Regent Park  43.6607  -79.3605
# 3         M5A  Downtown Toronto      Harbourfront  43.6401  -79.3801
# 4         M6A        North York    Lawrence Manor  43.7221  -79.4375

# %%
drop_unknown
# Out:
# [7, 39, 103, 105, 139, 176, 182, 188, 202, 203, 214]

# %%
data_new.iloc[7, :]
# Out:
# postal_code                                M7A
# Borough                       Downtown Toronto
# Neighborhood     Ontario Provincial Government
# Latitude
# Longitude
# Name: 7, dtype: object

# %%
import numpy as np
data_new['Latitude'].replace('', np.nan, inplace=True)
data_new.dropna(subset=['Latitude'], inplace=True)
data_new.shape
# Out:
# (206, 5)

# %%
data_new.reset_index(drop=True)
# Out:
#     postal_code           Borough               Neighborhood   Latitude  \
# 0           M3A        North York                  Parkwoods  43.761124
# 1           M4A        North York           Victoria Village  43.732658
# 2           M5A  Downtown Toronto                Regent Park  43.660706
# 3           M5A  Downtown Toronto               Harbourfront  43.640080
# 4           M6A        North York             Lawrence Manor  43.722079
# ..          ...               ...                        ...        ...
# 201         M8Y         Etobicoke   Kingsway Park South East  43.647381
# 202         M8Z         Etobicoke                  Mimico NW  43.616677
# 203         M8Z         Etobicoke         The Queensway West  43.623618
# 204         M8Z         Etobicoke   Kingsway Park South West  43.647381
# 205         M8Z         Etobicoke      Royal York South West  43.648183
#
#     Longitude
# 0    -79.3241
# 1    -79.3112
# 2    -79.3605
# 3    -79.3801
# 4    -79.4375
# ..        ...
# 201  -79.5113
# 202  -79.4968
# 203  -79.5148
# 204  -79.5113
# 205  -79.5113
#
# [206 rows x 5 columns]

# %%
data_new.head()
# Out:
#   postal_code           Borough      Neighborhood   Latitude Longitude
# 0         M3A        North York         Parkwoods  43.761124  -79.3241
# 1         M4A        North York  Victoria Village  43.732658  -79.3112
# 2         M5A  Downtown Toronto       Regent Park  43.660706  -79.3605
# 3         M5A  Downtown Toronto      Harbourfront  43.640080  -79.3801
# 4         M6A        North York    Lawrence Manor  43.722079  -79.4375

# %%
# now our dataframe is ready with geographical coordinates
data_new.to_csv('geo_data.csv')# save dataframe in geo_data file in csv format
